# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('customer.zip')
print(df.info())
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')
# x=df['SeniorCitizen'].value_counts()
# p=x.index
# q=x.values
# plt.xticks(p)
# plt.bar(p,q)
# plt.show()
# print(df['tenure'].agg(['max','min','mean']))
# print(df['MonthlyCharges'].mean())
# print(df['Churn'].value_counts())
# print(df['PaymentMethod'].value_counts())
# print(df['InternetService'].value_counts().idxmax())
# print(df['TotalCharges'].isna().sum())
# print(df['TotalCharges'].duplicated().sum())
# print(df['SeniorCitizen'].map({0:'No',1:'Yes'}))
# print(df['tenure'])
df['tenuregroup']=pd.cut(df['tenure'],bins=[0,12,30,float('inf')],labels=['new','mid','loyal'])
# print(df['tenuregroup'])
# sns.boxplot(x='MonthlyCharges',data=df)
sns.histplot(x='tenuregroup',data=df,kde=True)
# sns.boxplot(x='Contract',y='MonthlyCharges',data=df)
# plt.show()
# sns.boxplot(x='Churn',y='MonthlyCharges',data=df)
# print(df.groupby('gender')['Churn'].apply(lambda x: (x=='Yes').mean()))
# print(df.groupby('SeniorCitizen')['Churn'].apply(lambda x: (x=='Yes').mean()))
# print(df.groupby('Contract')['Churn'].value_counts())
# print(df.groupby('PaperlessBilling')['Churn'].apply(lambda x: (x=='Yes').mean()))
# print(df[df['InternetService']=='Fiber optic']['Churn'].apply(lambda x: x=="Yes").mean())
# print(df.groupby('InternetService')['Churn'].apply(lambda x:(x=="Yes").mean().max()))
# print(df['MonthlyCharges'].corr(df['TotalCharges']))
# sns.barplot(x='Churn',y='tenure',data=df)
# print(df.groupby('Churn')['MonthlyCharges'].mean())
# print(df.groupby('SeniorCitizen')['MonthlyCharges'].mean())
# sns.scatterplot(x='tenure',y='TotalCharges',data=df)
# plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...
